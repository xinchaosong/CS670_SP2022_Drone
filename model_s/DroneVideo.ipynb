# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' #to get rid of tensorflow CUDA warnings

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, Activation, Dense
import h5py
import pickle

# %%
class_names = ['down', 'left', 'move', 'noobscticle', 'right', 'stop', 'up']
pickled_model = pickle.load(open('model.pkl', 'rb'))
Video_FILE = "video/withobj.mp4"
video=cv2.VideoCapture(Video_FILE)

# %%
keymap = {
   'down': 'move down', 
   'left': 'move left', 
   'move': 'move toward object', 
   'noobscticle': 'no obstacle', 
   'right': 'move right', 
   'stop': 'drone stop', 
   'up': 'move up', 
}

# %%
cap = cv2.VideoCapture('video/withobj.mp4')
  
while(True):
    
    
    # Capture frames in the video
    ret, frame = cap.read()
    
    
    frame = cv2.resize(frame, (180, 180)) 
    img_array = tf.keras.utils.img_to_array(frame)
    img_array = tf.expand_dims(frame, 0) # Create a batch

   
    predictions = pickled_model.predict(img_array)

    score = tf.nn.softmax(predictions[0])

    print(
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
    
        
  
    # describe the type of font
    # to be used.
    font = cv2.FONT_HERSHEY_SIMPLEX
  
    # Use putText() method for
    # inserting text on video
    text = keymap.get(class_names[np.argmax(score)])   
    cv2.putText(frame, 
                text, 
                (10, 50), 
                font, 0.5, 
                (0, 255, 255), 
                2, 
                cv2.LINE_4)
  
    # Display the resulting frame
    imS = cv2.resize(frame, (960, 540))
    cv2.imshow('video', imS)
  
    # creating 'q' as the quit 
    # button for the video
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  
# release the cap object
cap.release()
# close all windows
cv2.destroyAllWindows()
# Out:
# This image most likely belongs to move with a 97.13 percent confidence.
# This image most likely belongs to move with a 97.81 percent confidence.
# This image most likely belongs to move with a 98.18 percent confidence.
# This image most likely belongs to move with a 98.19 percent confidence.
# This image most likely belongs to move with a 98.60 percent confidence.
# This image most likely belongs to move with a 98.96 percent confidence.
# This image most likely belongs to move with a 99.13 percent confidence.
# This image most likely belongs to move with a 99.53 percent confidence.
# This image most likely belongs to move with a 99.53 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.96 percent confidence.
# This image most likely belongs to move with a 99.98 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.98 percent confidence.
# This image most likely belongs to move with a 99.98 percent confidence.
# This image most likely belongs to move with a 99.98 percent confidence.
# This image most likely belongs to move with a 99.96 percent confidence.
# This image most likely belongs to move with a 99.95 percent confidence.
# This image most likely belongs to move with a 99.95 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.90 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.86 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.77 percent confidence.
# This image most likely belongs to move with a 99.72 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.92 percent confidence.
# This image most likely belongs to move with a 99.92 percent confidence.
# This image most likely belongs to move with a 99.84 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.93 percent confidence.
# This image most likely belongs to move with a 99.92 percent confidence.
# This image most likely belongs to move with a 99.82 percent confidence.
# This image most likely belongs to move with a 99.78 percent confidence.
# This image most likely belongs to move with a 99.52 percent confidence.
# This image most likely belongs to move with a 99.52 percent confidence.
# This image most likely belongs to move with a 99.58 percent confidence.
# This image most likely belongs to move with a 99.58 percent confidence.
# This image most likely belongs to move with a 99.68 percent confidence.
# This image most likely belongs to move with a 99.68 percent confidence.
# This image most likely belongs to move with a 99.69 percent confidence.
# This image most likely belongs to move with a 99.64 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.56 percent confidence.
# This image most likely belongs to move with a 99.39 percent confidence.
# This image most likely belongs to move with a 98.86 percent confidence.
# This image most likely belongs to move with a 96.36 percent confidence.
# This image most likely belongs to move with a 96.36 percent confidence.
# This image most likely belongs to move with a 83.98 percent confidence.
# This image most likely belongs to move with a 68.07 percent confidence.
# This image most likely belongs to stop with a 59.22 percent confidence.
# This image most likely belongs to stop with a 73.87 percent confidence.
# This image most likely belongs to stop with a 73.89 percent confidence.
# This image most likely belongs to stop with a 81.43 percent confidence.
# This image most likely belongs to stop with a 83.66 percent confidence.
# This image most likely belongs to stop with a 83.06 percent confidence.
# This image most likely belongs to stop with a 76.58 percent confidence.
# This image most likely belongs to stop with a 76.67 percent confidence.
# This image most likely belongs to stop with a 55.43 percent confidence.
# This image most likely belongs to stop with a 53.41 percent confidence.
# This image most likely belongs to move with a 50.40 percent confidence.
# This image most likely belongs to move with a 60.25 percent confidence.
# This image most likely belongs to stop with a 94.43 percent confidence.
# This image most likely belongs to stop with a 94.31 percent confidence.
# This image most likely belongs to stop with a 99.20 percent confidence.
# This image most likely belongs to stop with a 99.29 percent confidence.
# This image most likely belongs to stop with a 99.52 percent confidence.
# This image most likely belongs to stop with a 99.52 percent confidence.
# This image most likely belongs to stop with a 99.68 percent confidence.
# This image most likely belongs to stop with a 99.77 percent confidence.
# This image most likely belongs to stop with a 99.75 percent confidence.
# This image most likely belongs to stop with a 99.73 percent confidence.
# This image most likely belongs to stop with a 99.73 percent confidence.
# This image most likely belongs to stop with a 99.65 percent confidence.
# This image most likely belongs to stop with a 99.71 percent confidence.
# This image most likely belongs to stop with a 99.75 percent confidence.
# This image most likely belongs to stop with a 99.78 percent confidence.
# This image most likely belongs to stop with a 99.78 percent confidence.
# This image most likely belongs to stop with a 99.75 percent confidence.
# This image most likely belongs to stop with a 99.55 percent confidence.
# This image most likely belongs to stop with a 99.03 percent confidence.
# This image most likely belongs to stop with a 98.96 percent confidence.
# This image most likely belongs to stop with a 98.96 percent confidence.
# This image most likely belongs to stop with a 98.76 percent confidence.
# This image most likely belongs to stop with a 99.03 percent confidence.
# This image most likely belongs to stop with a 99.08 percent confidence.
# This image most likely belongs to stop with a 98.70 percent confidence.
# This image most likely belongs to stop with a 98.71 percent confidence.
# This image most likely belongs to stop with a 94.07 percent confidence.
# This image most likely belongs to stop with a 87.30 percent confidence.
# This image most likely belongs to stop with a 79.47 percent confidence.
# This image most likely belongs to stop with a 74.48 percent confidence.
# This image most likely belongs to stop with a 85.76 percent confidence.
# This image most likely belongs to stop with a 85.70 percent confidence.
# This image most likely belongs to stop with a 49.82 percent confidence.
# This image most likely belongs to stop with a 52.16 percent confidence.
# This image most likely belongs to stop with a 62.57 percent confidence.
# This image most likely belongs to stop with a 62.70 percent confidence.
# This image most likely belongs to stop with a 95.76 percent confidence.
# This image most likely belongs to stop with a 97.26 percent confidence.
# This image most likely belongs to stop with a 98.65 percent confidence.
# This image most likely belongs to stop with a 99.29 percent confidence.
# This image most likely belongs to stop with a 99.28 percent confidence.
# This image most likely belongs to stop with a 99.69 percent confidence.
# This image most likely belongs to stop with a 99.72 percent confidence.
# This image most likely belongs to stop with a 99.61 percent confidence.
# This image most likely belongs to stop with a 99.58 percent confidence.
# This image most likely belongs to stop with a 99.57 percent confidence.
# This image most likely belongs to stop with a 99.68 percent confidence.
# This image most likely belongs to stop with a 99.84 percent confidence.
# This image most likely belongs to stop with a 99.89 percent confidence.
# This image most likely belongs to stop with a 99.92 percent confidence.
# This image most likely belongs to stop with a 99.92 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.93 percent confidence.
# This image most likely belongs to stop with a 99.93 percent confidence.
# This image most likely belongs to stop with a 99.93 percent confidence.
# This image most likely belongs to stop with a 99.93 percent confidence.
# This image most likely belongs to stop with a 99.93 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.91 percent confidence.
# This image most likely belongs to stop with a 99.83 percent confidence.
# This image most likely belongs to stop with a 99.83 percent confidence.
# This image most likely belongs to stop with a 99.93 percent confidence.
# This image most likely belongs to stop with a 99.95 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.96 percent confidence.
# This image most likely belongs to stop with a 99.96 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.97 percent confidence.
# This image most likely belongs to stop with a 99.94 percent confidence.
# This image most likely belongs to stop with a 99.88 percent confidence.
# This image most likely belongs to stop with a 99.89 percent confidence.
# This image most likely belongs to stop with a 99.75 percent confidence.
# This image most likely belongs to stop with a 99.75 percent confidence.
# This image most likely belongs to stop with a 99.01 percent confidence.
# This image most likely belongs to stop with a 98.40 percent confidence.
# This image most likely belongs to stop with a 97.73 percent confidence.
# This image most likely belongs to stop with a 96.27 percent confidence.
# This image most likely belongs to stop with a 96.24 percent confidence.
# This image most likely belongs to stop with a 49.76 percent confidence.
# This image most likely belongs to right with a 52.45 percent confidence.
# This image most likely belongs to right with a 50.99 percent confidence.
# This image most likely belongs to right with a 51.51 percent confidence.
# This image most likely belongs to right with a 51.39 percent confidence.
# This image most likely belongs to stop with a 55.63 percent confidence.
# This image most likely belongs to stop with a 63.43 percent confidence.
# This image most likely belongs to stop with a 70.29 percent confidence.
# This image most likely belongs to stop with a 72.28 percent confidence.
# This image most likely belongs to stop with a 72.16 percent confidence.
# This image most likely belongs to stop with a 67.37 percent confidence.
# This image most likely belongs to stop with a 62.18 percent confidence.
# This image most likely belongs to stop with a 61.02 percent confidence.
# This image most likely belongs to stop with a 55.55 percent confidence.
# This image most likely belongs to right with a 58.74 percent confidence.
# This image most likely belongs to right with a 58.84 percent confidence.
# This image most likely belongs to right with a 72.81 percent confidence.
# This image most likely belongs to right with a 82.20 percent confidence.
# This image most likely belongs to right with a 91.88 percent confidence.
# This image most likely belongs to right with a 91.96 percent confidence.
# This image most likely belongs to right with a 99.21 percent confidence.
# This image most likely belongs to right with a 99.67 percent confidence.
# This image most likely belongs to right with a 99.91 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.83 percent confidence.
# This image most likely belongs to right with a 99.83 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.98 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.90 percent confidence.
# This image most likely belongs to right with a 99.88 percent confidence.
# This image most likely belongs to right with a 99.90 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.93 percent confidence.
# This image most likely belongs to right with a 99.93 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.97 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.94 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.92 percent confidence.
# This image most likely belongs to right with a 99.92 percent confidence.
# This image most likely belongs to right with a 99.92 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.85 percent confidence.
# This image most likely belongs to right with a 99.84 percent confidence.
# This image most likely belongs to right with a 99.77 percent confidence.
# This image most likely belongs to right with a 99.82 percent confidence.
# This image most likely belongs to right with a 99.92 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.91 percent confidence.
# This image most likely belongs to right with a 99.91 percent confidence.
# This image most likely belongs to right with a 96.18 percent confidence.
# This image most likely belongs to right with a 62.75 percent confidence.
# This image most likely belongs to move with a 75.60 percent confidence.
# This image most likely belongs to move with a 75.65 percent confidence.
# This image most likely belongs to stop with a 53.55 percent confidence.
# This image most likely belongs to stop with a 38.39 percent confidence.
# This image most likely belongs to right with a 72.21 percent confidence.
# This image most likely belongs to right with a 89.83 percent confidence.
# This image most likely belongs to right with a 89.86 percent confidence.
# This image most likely belongs to right with a 58.23 percent confidence.
# This image most likely belongs to right with a 68.17 percent confidence.
# This image most likely belongs to right with a 86.25 percent confidence.
# This image most likely belongs to right with a 86.05 percent confidence.
# This image most likely belongs to right with a 86.05 percent confidence.
# This image most likely belongs to right with a 63.87 percent confidence.
# This image most likely belongs to right with a 77.68 percent confidence.
# This image most likely belongs to right with a 76.29 percent confidence.
# This image most likely belongs to right with a 82.85 percent confidence.
# This image most likely belongs to right with a 82.86 percent confidence.
# This image most likely belongs to right with a 93.13 percent confidence.
# This image most likely belongs to right with a 95.29 percent confidence.
# This image most likely belongs to right with a 96.17 percent confidence.
# This image most likely belongs to right with a 96.42 percent confidence.
# This image most likely belongs to right with a 96.41 percent confidence.
# This image most likely belongs to right with a 96.94 percent confidence.
# This image most likely belongs to right with a 97.32 percent confidence.
# This image most likely belongs to right with a 97.74 percent confidence.
# This image most likely belongs to right with a 99.31 percent confidence.
# This image most likely belongs to right with a 99.72 percent confidence.
# This image most likely belongs to right with a 99.72 percent confidence.
# This image most likely belongs to right with a 99.78 percent confidence.
# This image most likely belongs to right with a 99.84 percent confidence.
# This image most likely belongs to right with a 99.85 percent confidence.
# This image most likely belongs to right with a 99.85 percent confidence.
# This image most likely belongs to right with a 99.59 percent confidence.
# This image most likely belongs to right with a 98.89 percent confidence.
# This image most likely belongs to right with a 96.45 percent confidence.
# This image most likely belongs to right with a 95.76 percent confidence.
# This image most likely belongs to right with a 95.76 percent confidence.
# This image most likely belongs to right with a 91.57 percent confidence.
# This image most likely belongs to right with a 79.02 percent confidence.
# This image most likely belongs to right with a 53.37 percent confidence.
# This image most likely belongs to move with a 77.26 percent confidence.
# This image most likely belongs to move with a 77.30 percent confidence.
# This image most likely belongs to move with a 85.29 percent confidence.
# This image most likely belongs to move with a 89.39 percent confidence.
# This image most likely belongs to move with a 50.37 percent confidence.
# This image most likely belongs to right with a 75.73 percent confidence.
# This image most likely belongs to right with a 75.77 percent confidence.
# This image most likely belongs to right with a 97.71 percent confidence.
# This image most likely belongs to right with a 92.42 percent confidence.
# This image most likely belongs to right with a 95.79 percent confidence.
# This image most likely belongs to right with a 99.36 percent confidence.
# This image most likely belongs to right with a 99.36 percent confidence.
# This image most likely belongs to right with a 99.82 percent confidence.
# This image most likely belongs to right with a 99.77 percent confidence.
# This image most likely belongs to right with a 99.81 percent confidence.
# This image most likely belongs to right with a 99.86 percent confidence.
# This image most likely belongs to right with a 99.72 percent confidence.
# This image most likely belongs to right with a 99.72 percent confidence.
# This image most likely belongs to right with a 99.50 percent confidence.
# This image most likely belongs to right with a 99.28 percent confidence.
# This image most likely belongs to right with a 99.59 percent confidence.
# This image most likely belongs to right with a 99.59 percent confidence.
# This image most likely belongs to right with a 99.80 percent confidence.
# This image most likely belongs to right with a 99.68 percent confidence.
# This image most likely belongs to right with a 99.47 percent confidence.
# This image most likely belongs to right with a 99.69 percent confidence.
# This image most likely belongs to right with a 99.70 percent confidence.
# This image most likely belongs to right with a 99.73 percent confidence.
# This image most likely belongs to right with a 99.76 percent confidence.
# This image most likely belongs to right with a 99.85 percent confidence.
# This image most likely belongs to right with a 99.90 percent confidence.
# This image most likely belongs to right with a 99.90 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.93 percent confidence.
# This image most likely belongs to right with a 99.89 percent confidence.
# This image most likely belongs to right with a 99.89 percent confidence.
# This image most likely belongs to right with a 99.87 percent confidence.
# This image most likely belongs to right with a 99.87 percent confidence.
# This image most likely belongs to right with a 99.82 percent confidence.
# This image most likely belongs to right with a 99.70 percent confidence.
# This image most likely belongs to right with a 99.52 percent confidence.
# This image most likely belongs to right with a 99.52 percent confidence.
# This image most likely belongs to right with a 99.16 percent confidence.
# This image most likely belongs to right with a 98.49 percent confidence.
# This image most likely belongs to right with a 98.01 percent confidence.
# This image most likely belongs to right with a 98.01 percent confidence.
# This image most likely belongs to right with a 97.65 percent confidence.
# This image most likely belongs to right with a 97.67 percent confidence.
# This image most likely belongs to right with a 98.79 percent confidence.
# This image most likely belongs to right with a 99.39 percent confidence.
# This image most likely belongs to right with a 99.40 percent confidence.
# This image most likely belongs to right with a 99.78 percent confidence.
# This image most likely belongs to right with a 99.85 percent confidence.
# This image most likely belongs to right with a 99.87 percent confidence.
# This image most likely belongs to right with a 99.88 percent confidence.
# This image most likely belongs to right with a 99.88 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.95 percent confidence.
# This image most likely belongs to right with a 99.93 percent confidence.
# This image most likely belongs to right with a 99.93 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.86 percent confidence.
# This image most likely belongs to right with a 99.47 percent confidence.
# This image most likely belongs to right with a 98.43 percent confidence.
# This image most likely belongs to right with a 98.43 percent confidence.
# This image most likely belongs to right with a 58.60 percent confidence.
# This image most likely belongs to right with a 68.53 percent confidence.
# This image most likely belongs to right with a 97.24 percent confidence.
# This image most likely belongs to right with a 99.77 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.96 percent confidence.
# This image most likely belongs to right with a 99.85 percent confidence.
# This image most likely belongs to right with a 99.24 percent confidence.
# This image most likely belongs to right with a 97.07 percent confidence.
# This image most likely belongs to right with a 97.07 percent confidence.
# This image most likely belongs to right with a 98.18 percent confidence.
# This image most likely belongs to right with a 99.00 percent confidence.
# This image most likely belongs to right with a 99.29 percent confidence.
# This image most likely belongs to right with a 98.95 percent confidence.
# This image most likely belongs to right with a 98.95 percent confidence.
# This image most likely belongs to right with a 98.70 percent confidence.
# This image most likely belongs to right with a 99.35 percent confidence.
# This image most likely belongs to right with a 99.14 percent confidence.
# This image most likely belongs to right with a 98.88 percent confidence.
# This image most likely belongs to right with a 98.88 percent confidence.
# This image most likely belongs to right with a 98.97 percent confidence.
# This image most likely belongs to right with a 99.13 percent confidence.
# This image most likely belongs to right with a 99.25 percent confidence.
# This image most likely belongs to right with a 98.86 percent confidence.
# This image most likely belongs to right with a 98.86 percent confidence.
# This image most likely belongs to right with a 95.63 percent confidence.
# This image most likely belongs to right with a 95.02 percent confidence.
# This image most likely belongs to right with a 96.65 percent confidence.
# This image most likely belongs to right with a 97.85 percent confidence.
# This image most likely belongs to right with a 97.85 percent confidence.
# This image most likely belongs to right with a 98.11 percent confidence.
# This image most likely belongs to right with a 98.24 percent confidence.
# This image most likely belongs to right with a 98.79 percent confidence.
# This image most likely belongs to right with a 98.66 percent confidence.
# This image most likely belongs to right with a 97.37 percent confidence.
# This image most likely belongs to right with a 97.36 percent confidence.
# This image most likely belongs to right with a 97.13 percent confidence.
# This image most likely belongs to right with a 95.93 percent confidence.
# This image most likely belongs to right with a 94.10 percent confidence.
# This image most likely belongs to right with a 94.11 percent confidence.
# This image most likely belongs to right with a 93.67 percent confidence.
# This image most likely belongs to right with a 92.93 percent confidence.
# This image most likely belongs to right with a 92.46 percent confidence.
# This image most likely belongs to right with a 90.77 percent confidence.
# This image most likely belongs to right with a 90.72 percent confidence.
# This image most likely belongs to right with a 93.75 percent confidence.
# This image most likely belongs to right with a 90.36 percent confidence.
# This image most likely belongs to right with a 92.77 percent confidence.
# This image most likely belongs to right with a 97.82 percent confidence.
# This image most likely belongs to right with a 97.83 percent confidence.
# This image most likely belongs to right with a 97.93 percent confidence.
# This image most likely belongs to right with a 99.06 percent confidence.
# This image most likely belongs to right with a 99.36 percent confidence.
# This image most likely belongs to right with a 98.44 percent confidence.
# This image most likely belongs to right with a 98.43 percent confidence.
# This image most likely belongs to right with a 99.68 percent confidence.
# This image most likely belongs to right with a 99.76 percent confidence.
# This image most likely belongs to right with a 99.63 percent confidence.
# This image most likely belongs to right with a 99.17 percent confidence.
# This image most likely belongs to right with a 99.17 percent confidence.
# This image most likely belongs to right with a 98.40 percent confidence.
# This image most likely belongs to right with a 99.12 percent confidence.
# This image most likely belongs to right with a 98.09 percent confidence.
# This image most likely belongs to right with a 97.45 percent confidence.
# This image most likely belongs to right with a 98.80 percent confidence.
# This image most likely belongs to right with a 98.80 percent confidence.
# This image most likely belongs to right with a 97.92 percent confidence.
# This image most likely belongs to right with a 90.62 percent confidence.
# This image most likely belongs to right with a 60.57 percent confidence.
# This image most likely belongs to right with a 60.63 percent confidence.
# This image most likely belongs to right with a 68.94 percent confidence.
# This image most likely belongs to right with a 69.03 percent confidence.
# This image most likely belongs to right with a 61.91 percent confidence.
# This image most likely belongs to right with a 86.70 percent confidence.
# This image most likely belongs to right with a 86.64 percent confidence.
# This image most likely belongs to right with a 98.77 percent confidence.
# This image most likely belongs to right with a 98.68 percent confidence.
# This image most likely belongs to right with a 98.81 percent confidence.
# This image most likely belongs to right with a 98.63 percent confidence.
# This image most likely belongs to right with a 98.62 percent confidence.
# This image most likely belongs to right with a 95.57 percent confidence.
# This image most likely belongs to right with a 96.31 percent confidence.
# This image most likely belongs to right with a 98.42 percent confidence.
# This image most likely belongs to right with a 98.40 percent confidence.
# This image most likely belongs to right with a 98.41 percent confidence.
# This image most likely belongs to right with a 98.31 percent confidence.
# This image most likely belongs to right with a 96.83 percent confidence.
# This image most likely belongs to right with a 95.67 percent confidence.
# This image most likely belongs to right with a 93.26 percent confidence.
# This image most likely belongs to right with a 93.30 percent confidence.
# This image most likely belongs to right with a 77.09 percent confidence.
# This image most likely belongs to right with a 79.45 percent confidence.
# This image most likely belongs to right with a 69.14 percent confidence.
# This image most likely belongs to right with a 64.26 percent confidence.
# This image most likely belongs to right with a 94.55 percent confidence.
# This image most likely belongs to right with a 94.55 percent confidence.
# This image most likely belongs to move with a 51.25 percent confidence.
# This image most likely belongs to move with a 96.61 percent confidence.
# This image most likely belongs to move with a 99.21 percent confidence.
# This image most likely belongs to move with a 99.21 percent confidence.
# This image most likely belongs to move with a 58.46 percent confidence.
# This image most likely belongs to right with a 71.34 percent confidence.
# This image most likely belongs to right with a 49.10 percent confidence.
# This image most likely belongs to right with a 40.35 percent confidence.
# This image most likely belongs to right with a 40.38 percent confidence.
# This image most likely belongs to move with a 70.30 percent confidence.
# This image most likely belongs to move with a 71.47 percent confidence.
# This image most likely belongs to move with a 82.15 percent confidence.
# This image most likely belongs to move with a 90.56 percent confidence.
# This image most likely belongs to move with a 90.58 percent confidence.
# This image most likely belongs to move with a 96.77 percent confidence.
# This image most likely belongs to move with a 97.22 percent confidence.
# This image most likely belongs to move with a 96.42 percent confidence.
# This image most likely belongs to move with a 95.15 percent confidence.
# This image most likely belongs to move with a 95.13 percent confidence.
# This image most likely belongs to move with a 95.61 percent confidence.
# This image most likely belongs to move with a 94.88 percent confidence.
# This image most likely belongs to move with a 89.72 percent confidence.
# This image most likely belongs to move with a 80.92 percent confidence.
# This image most likely belongs to move with a 80.89 percent confidence.
# This image most likely belongs to move with a 98.04 percent confidence.
# This image most likely belongs to move with a 99.41 percent confidence.
# This image most likely belongs to move with a 99.70 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.78 percent confidence.
# This image most likely belongs to move with a 99.78 percent confidence.
# This image most likely belongs to move with a 99.80 percent confidence.
# This image most likely belongs to move with a 99.74 percent confidence.
# This image most likely belongs to move with a 99.79 percent confidence.
# This image most likely belongs to move with a 99.50 percent confidence.
# This image most likely belongs to move with a 99.49 percent confidence.
# This image most likely belongs to move with a 99.44 percent confidence.
# This image most likely belongs to move with a 99.64 percent confidence.
# This image most likely belongs to move with a 99.70 percent confidence.
# This image most likely belongs to move with a 99.55 percent confidence.
# This image most likely belongs to move with a 99.55 percent confidence.
# This image most likely belongs to move with a 99.29 percent confidence.
# This image most likely belongs to move with a 99.13 percent confidence.
# This image most likely belongs to move with a 98.96 percent confidence.
# This image most likely belongs to move with a 98.65 percent confidence.
# This image most likely belongs to move with a 98.66 percent confidence.
# This image most likely belongs to move with a 99.49 percent confidence.
# This image most likely belongs to move with a 99.83 percent confidence.
# This image most likely belongs to move with a 99.95 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.97 percent confidence.
# This image most likely belongs to move with a 99.98 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.84 percent confidence.
# This image most likely belongs to move with a 99.84 percent confidence.
# This image most likely belongs to move with a 96.85 percent confidence.
# This image most likely belongs to move with a 89.76 percent confidence.
# This image most likely belongs to move with a 66.77 percent confidence.
# This image most likely belongs to move with a 67.02 percent confidence.
# This image most likely belongs to move with a 66.93 percent confidence.
# This image most likely belongs to left with a 60.19 percent confidence.
# This image most likely belongs to down with a 74.74 percent confidence.
# This image most likely belongs to down with a 96.50 percent confidence.
# This image most likely belongs to down with a 99.15 percent confidence.
# This image most likely belongs to down with a 99.15 percent confidence.
# This image most likely belongs to down with a 99.42 percent confidence.
# This image most likely belongs to down with a 99.63 percent confidence.
# This image most likely belongs to down with a 99.63 percent confidence.
# This image most likely belongs to down with a 99.75 percent confidence.
# This image most likely belongs to down with a 99.75 percent confidence.
# This image most likely belongs to down with a 99.80 percent confidence.
# This image most likely belongs to down with a 99.85 percent confidence.
# This image most likely belongs to down with a 99.83 percent confidence.
# This image most likely belongs to down with a 99.81 percent confidence.
# This image most likely belongs to down with a 99.82 percent confidence.
# This image most likely belongs to down with a 99.52 percent confidence.
# This image most likely belongs to down with a 99.18 percent confidence.
# This image most likely belongs to down with a 99.58 percent confidence.
# This image most likely belongs to down with a 99.79 percent confidence.
# This image most likely belongs to down with a 99.79 percent confidence.
# This image most likely belongs to down with a 99.56 percent confidence.
# This image most likely belongs to down with a 99.51 percent confidence.
# This image most likely belongs to down with a 99.67 percent confidence.
# This image most likely belongs to down with a 99.78 percent confidence.
# This image most likely belongs to down with a 99.78 percent confidence.
# This image most likely belongs to down with a 99.76 percent confidence.
# This image most likely belongs to down with a 99.76 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.82 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.84 percent confidence.
# This image most likely belongs to down with a 99.74 percent confidence.
# This image most likely belongs to down with a 99.74 percent confidence.
# This image most likely belongs to down with a 99.91 percent confidence.
# This image most likely belongs to down with a 99.84 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.89 percent confidence.
# This image most likely belongs to down with a 99.89 percent confidence.
# This image most likely belongs to down with a 96.43 percent confidence.
# This image most likely belongs to down with a 86.88 percent confidence.
# This image most likely belongs to down with a 87.21 percent confidence.
# This image most likely belongs to down with a 59.17 percent confidence.
# This image most likely belongs to down with a 59.13 percent confidence.
# This image most likely belongs to left with a 82.61 percent confidence.
# This image most likely belongs to left with a 86.16 percent confidence.
# This image most likely belongs to left with a 89.70 percent confidence.
# This image most likely belongs to left with a 90.60 percent confidence.
# This image most likely belongs to left with a 90.65 percent confidence.
# This image most likely belongs to left with a 84.88 percent confidence.
# This image most likely belongs to left with a 67.60 percent confidence.
# This image most likely belongs to down with a 67.42 percent confidence.
# This image most likely belongs to down with a 82.29 percent confidence.
# This image most likely belongs to down with a 82.31 percent confidence.
# This image most likely belongs to down with a 86.99 percent confidence.
# This image most likely belongs to down with a 84.66 percent confidence.
# This image most likely belongs to down with a 89.44 percent confidence.
# This image most likely belongs to down with a 89.41 percent confidence.
# This image most likely belongs to down with a 89.41 percent confidence.
# This image most likely belongs to down with a 78.23 percent confidence.
# This image most likely belongs to down with a 87.61 percent confidence.
# This image most likely belongs to down with a 88.45 percent confidence.
# This image most likely belongs to down with a 88.96 percent confidence.
# This image most likely belongs to down with a 88.98 percent confidence.
# This image most likely belongs to down with a 97.65 percent confidence.
# This image most likely belongs to down with a 98.90 percent confidence.
# This image most likely belongs to down with a 99.56 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.80 percent confidence.
# This image most likely belongs to down with a 99.75 percent confidence.
# This image most likely belongs to down with a 99.67 percent confidence.
# This image most likely belongs to down with a 99.68 percent confidence.
# This image most likely belongs to down with a 99.68 percent confidence.
# This image most likely belongs to down with a 99.93 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.87 percent confidence.
# This image most likely belongs to down with a 99.86 percent confidence.
# This image most likely belongs to down with a 99.87 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.65 percent confidence.
# This image most likely belongs to down with a 98.63 percent confidence.
# This image most likely belongs to down with a 98.04 percent confidence.
# This image most likely belongs to down with a 98.05 percent confidence.
# This image most likely belongs to down with a 97.98 percent confidence.
# This image most likely belongs to down with a 98.09 percent confidence.
# This image most likely belongs to down with a 99.48 percent confidence.
# This image most likely belongs to down with a 99.48 percent confidence.
# This image most likely belongs to down with a 99.49 percent confidence.
# This image most likely belongs to down with a 99.93 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# This image most likely belongs to down with a 99.82 percent confidence.
# This image most likely belongs to down with a 99.76 percent confidence.
# This image most likely belongs to down with a 99.76 percent confidence.
# This image most likely belongs to down with a 99.53 percent confidence.
# This image most likely belongs to down with a 99.66 percent confidence.
# This image most likely belongs to down with a 99.61 percent confidence.
# This image most likely belongs to down with a 99.72 percent confidence.
# This image most likely belongs to down with a 99.72 percent confidence.
# This image most likely belongs to down with a 99.75 percent confidence.
# This image most likely belongs to down with a 99.84 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.93 percent confidence.
# This image most likely belongs to down with a 99.93 percent confidence.
# This image most likely belongs to down with a 99.93 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.92 percent confidence.
# This image most likely belongs to down with a 99.91 percent confidence.
# This image most likely belongs to down with a 99.91 percent confidence.
# This image most likely belongs to down with a 99.91 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.89 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.90 percent confidence.
# This image most likely belongs to down with a 99.88 percent confidence.
# ...
# This image most likely belongs to move with a 99.88 percent confidence.
# This image most likely belongs to move with a 99.74 percent confidence.
# This image most likely belongs to move with a 99.71 percent confidence.
# This image most likely belongs to move with a 99.71 percent confidence.
# This image most likely belongs to move with a 99.70 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.70 percent confidence.
# This image most likely belongs to move with a 99.60 percent confidence.
# This image most likely belongs to move with a 99.60 percent confidence.
# This image most likely belongs to move with a 99.53 percent confidence.
# This image most likely belongs to move with a 99.55 percent confidence.
# This image most likely belongs to move with a 99.56 percent confidence.
# This image most likely belongs to move with a 99.55 percent confidence.
# This image most likely belongs to move with a 99.55 percent confidence.
# This image most likely belongs to move with a 99.60 percent confidence.
# This image most likely belongs to move with a 99.80 percent confidence.
# This image most likely belongs to move with a 99.79 percent confidence.
# This image most likely belongs to move with a 99.79 percent confidence.
# This image most likely belongs to move with a 99.79 percent confidence.
# This image most likely belongs to move with a 99.59 percent confidence.
# This image most likely belongs to move with a 99.59 percent confidence.
# This image most likely belongs to move with a 99.59 percent confidence.
# This image most likely belongs to move with a 99.49 percent confidence.
# This image most likely belongs to move with a 99.49 percent confidence.
# This image most likely belongs to move with a 99.44 percent confidence.
# This image most likely belongs to move with a 99.37 percent confidence.
# This image most likely belongs to move with a 99.43 percent confidence.
# This image most likely belongs to move with a 99.41 percent confidence.
# This image most likely belongs to move with a 99.40 percent confidence.
# This image most likely belongs to move with a 99.69 percent confidence.
# This image most likely belongs to move with a 99.68 percent confidence.
# This image most likely belongs to move with a 99.69 percent confidence.
# This image most likely belongs to move with a 99.64 percent confidence.
# This image most likely belongs to move with a 99.64 percent confidence.
# This image most likely belongs to move with a 99.65 percent confidence.
# This image most likely belongs to move with a 99.79 percent confidence.
# This image most likely belongs to move with a 99.78 percent confidence.
# This image most likely belongs to move with a 99.72 percent confidence.
# This image most likely belongs to move with a 99.72 percent confidence.
# This image most likely belongs to move with a 99.38 percent confidence.
# This image most likely belongs to move with a 99.13 percent confidence.
# This image most likely belongs to move with a 98.79 percent confidence.
# This image most likely belongs to move with a 98.82 percent confidence.
# This image most likely belongs to move with a 98.80 percent confidence.
# This image most likely belongs to move with a 98.98 percent confidence.
# This image most likely belongs to move with a 99.33 percent confidence.
# This image most likely belongs to move with a 99.34 percent confidence.
# This image most likely belongs to move with a 99.74 percent confidence.
# This image most likely belongs to move with a 99.74 percent confidence.
# This image most likely belongs to move with a 99.83 percent confidence.
# This image most likely belongs to move with a 99.60 percent confidence.
# This image most likely belongs to move with a 99.73 percent confidence.
# This image most likely belongs to move with a 99.65 percent confidence.
# This image most likely belongs to move with a 99.65 percent confidence.
# This image most likely belongs to move with a 99.80 percent confidence.
# This image most likely belongs to move with a 99.80 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.87 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.78 percent confidence.
# This image most likely belongs to move with a 99.31 percent confidence.
# This image most likely belongs to move with a 99.31 percent confidence.
# This image most likely belongs to move with a 98.97 percent confidence.
# This image most likely belongs to move with a 99.06 percent confidence.
# This image most likely belongs to move with a 98.22 percent confidence.
# This image most likely belongs to move with a 98.84 percent confidence.
# This image most likely belongs to move with a 98.83 percent confidence.
# This image most likely belongs to move with a 98.97 percent confidence.
# This image most likely belongs to move with a 97.62 percent confidence.
# This image most likely belongs to move with a 98.14 percent confidence.
# This image most likely belongs to move with a 97.99 percent confidence.
# This image most likely belongs to move with a 97.99 percent confidence.
# This image most likely belongs to move with a 96.82 percent confidence.
# This image most likely belongs to move with a 98.65 percent confidence.
# This image most likely belongs to move with a 98.64 percent confidence.
# This image most likely belongs to move with a 99.25 percent confidence.
# This image most likely belongs to move with a 99.25 percent confidence.
# This image most likely belongs to move with a 97.53 percent confidence.
# This image most likely belongs to move with a 95.02 percent confidence.
# This image most likely belongs to move with a 95.36 percent confidence.
# This image most likely belongs to move with a 95.39 percent confidence.
# This image most likely belongs to move with a 95.43 percent confidence.
# This image most likely belongs to move with a 94.34 percent confidence.
# This image most likely belongs to move with a 98.20 percent confidence.
# This image most likely belongs to move with a 98.90 percent confidence.
# This image most likely belongs to move with a 98.99 percent confidence.
# This image most likely belongs to move with a 99.00 percent confidence.
# This image most likely belongs to move with a 98.54 percent confidence.
# This image most likely belongs to move with a 97.76 percent confidence.
# This image most likely belongs to move with a 95.36 percent confidence.
# This image most likely belongs to move with a 80.95 percent confidence.
# This image most likely belongs to move with a 80.92 percent confidence.
# This image most likely belongs to move with a 58.11 percent confidence.
# This image most likely belongs to move with a 55.55 percent confidence.
# This image most likely belongs to move with a 68.69 percent confidence.
# This image most likely belongs to move with a 98.31 percent confidence.
# This image most likely belongs to move with a 98.30 percent confidence.
# This image most likely belongs to move with a 93.52 percent confidence.
# This image most likely belongs to move with a 97.57 percent confidence.
# This image most likely belongs to move with a 98.29 percent confidence.
# This image most likely belongs to move with a 97.30 percent confidence.
# This image most likely belongs to move with a 97.30 percent confidence.
# This image most likely belongs to move with a 71.37 percent confidence.
# This image most likely belongs to move with a 95.23 percent confidence.
# This image most likely belongs to move with a 95.20 percent confidence.
# This image most likely belongs to move with a 98.48 percent confidence.
# This image most likely belongs to move with a 98.48 percent confidence.
# This image most likely belongs to move with a 98.00 percent confidence.
# This image most likely belongs to move with a 98.69 percent confidence.
# This image most likely belongs to move with a 98.13 percent confidence.
# This image most likely belongs to move with a 89.11 percent confidence.
# This image most likely belongs to move with a 89.03 percent confidence.
# This image most likely belongs to move with a 87.79 percent confidence.
# This image most likely belongs to move with a 93.42 percent confidence.
# This image most likely belongs to move with a 95.78 percent confidence.
# This image most likely belongs to move with a 94.93 percent confidence.
# This image most likely belongs to move with a 94.92 percent confidence.
# This image most likely belongs to down with a 59.59 percent confidence.
# This image most likely belongs to down with a 61.94 percent confidence.
# This image most likely belongs to down with a 42.34 percent confidence.
# This image most likely belongs to move with a 49.61 percent confidence.
# This image most likely belongs to move with a 49.44 percent confidence.
# This image most likely belongs to move with a 89.89 percent confidence.
# This image most likely belongs to move with a 94.42 percent confidence.
# This image most likely belongs to move with a 98.06 percent confidence.
# This image most likely belongs to move with a 98.42 percent confidence.
# This image most likely belongs to move with a 98.41 percent confidence.
# This image most likely belongs to move with a 93.34 percent confidence.
# This image most likely belongs to move with a 80.52 percent confidence.
# This image most likely belongs to down with a 50.59 percent confidence.
# This image most likely belongs to down with a 65.40 percent confidence.
# This image most likely belongs to down with a 65.46 percent confidence.
# This image most likely belongs to down with a 94.32 percent confidence.
# This image most likely belongs to down with a 88.27 percent confidence.
# This image most likely belongs to down with a 88.27 percent confidence.
# This image most likely belongs to down with a 84.33 percent confidence.
# This image most likely belongs to down with a 84.32 percent confidence.
# This image most likely belongs to down with a 70.49 percent confidence.
# This image most likely belongs to down with a 72.98 percent confidence.
# This image most likely belongs to down with a 55.36 percent confidence.
# This image most likely belongs to down with a 51.41 percent confidence.
# This image most likely belongs to down with a 51.41 percent confidence.
# This image most likely belongs to left with a 48.44 percent confidence.
# This image most likely belongs to down with a 41.89 percent confidence.
# This image most likely belongs to move with a 79.14 percent confidence.
# This image most likely belongs to move with a 96.33 percent confidence.
# This image most likely belongs to move with a 96.34 percent confidence.
# This image most likely belongs to move with a 98.16 percent confidence.
# This image most likely belongs to move with a 98.93 percent confidence.
# This image most likely belongs to move with a 99.27 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.92 percent confidence.
# This image most likely belongs to move with a 99.89 percent confidence.
# This image most likely belongs to move with a 99.86 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.88 percent confidence.
# This image most likely belongs to move with a 99.94 percent confidence.
# This image most likely belongs to move with a 99.89 percent confidence.
# This image most likely belongs to move with a 99.82 percent confidence.
# This image most likely belongs to move with a 99.82 percent confidence.
# This image most likely belongs to move with a 99.91 percent confidence.
# This image most likely belongs to move with a 99.72 percent confidence.
# This image most likely belongs to move with a 99.73 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.36 percent confidence.
# This image most likely belongs to move with a 99.21 percent confidence.
# This image most likely belongs to move with a 98.80 percent confidence.
# This image most likely belongs to move with a 98.90 percent confidence.
# This image most likely belongs to move with a 98.90 percent confidence.
# This image most likely belongs to move with a 99.00 percent confidence.
# This image most likely belongs to move with a 99.40 percent confidence.
# This image most likely belongs to move with a 99.36 percent confidence.
# This image most likely belongs to move with a 99.22 percent confidence.
# This image most likely belongs to move with a 99.19 percent confidence.
# This image most likely belongs to move with a 99.34 percent confidence.
# This image most likely belongs to move with a 99.44 percent confidence.
# This image most likely belongs to move with a 99.62 percent confidence.
# This image most likely belongs to move with a 99.47 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.85 percent confidence.
# This image most likely belongs to move with a 99.90 percent confidence.
# This image most likely belongs to move with a 99.90 percent confidence.
# This image most likely belongs to move with a 99.92 percent confidence.
# This image most likely belongs to move with a 99.92 percent confidence.
# This image most likely belongs to move with a 99.88 percent confidence.
# This image most likely belongs to move with a 99.77 percent confidence.
# This image most likely belongs to move with a 99.53 percent confidence.
# This image most likely belongs to move with a 99.50 percent confidence.
# This image most likely belongs to move with a 99.50 percent confidence.
# This image most likely belongs to move with a 99.69 percent confidence.
# This image most likely belongs to move with a 99.69 percent confidence.
# This image most likely belongs to move with a 99.75 percent confidence.
# This image most likely belongs to move with a 99.70 percent confidence.
# This image most likely belongs to move with a 99.70 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.73 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.72 percent confidence.
# This image most likely belongs to move with a 99.72 percent confidence.
# This image most likely belongs to move with a 99.76 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.81 percent confidence.
# This image most likely belongs to move with a 99.85 percent confidence.
# This image most likely belongs to move with a 99.85 percent confidence.
# This image most likely belongs to move with a 99.86 percent confidence.
# This image most likely belongs to move with a 99.86 percent confidence.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_1594314/3627331800.py in <module>
#       8
#       9
# ---> 10     frame = cv2.resize(frame, (180, 180))
#      11     img_array = tf.keras.utils.img_to_array(frame)
#      12     img_array = tf.expand_dims(frame, 0) # Create a batch
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
